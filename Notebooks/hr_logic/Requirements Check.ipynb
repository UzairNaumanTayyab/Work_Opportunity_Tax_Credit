# %%
# !pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

for root, dirs, files in os.walk("/content/drive/MyDrive/Data Engineering Project"):
    print(root)
    for d in dirs:
        print("  DIR:", d)
    for f in files:
        print("  FILE:", f)
# Out:
# /content/drive/MyDrive/Data Engineering Project
#   DIR: Datasets
#   DIR: Notebooks
#   DIR: Scripts
#   DIR: dags
# /content/drive/MyDrive/Data Engineering Project/Datasets
#   FILE: Dataset 1 Description.gdoc
#   FILE: Dataset1.gsheet
#   FILE: Dataset1.csv
# /content/drive/MyDrive/Data Engineering Project/Notebooks
#   DIR: Create Datasets
#   DIR: hr_logic
# /content/drive/MyDrive/Data Engineering Project/Notebooks/Create Datasets
#   FILE: Create Dataset1.ipynb
# /content/drive/MyDrive/Data Engineering Project/Notebooks/hr_logic
#   FILE: hire.ipynb
#   FILE: Requirements Check.ipynb
#   FILE: simulate_day.ipynb
#   FILE: fire_employee.ipynb
# /content/drive/MyDrive/Data Engineering Project/Scripts
#   FILE: hire.py
#   FILE: fire_employee.py
#   FILE: simulate_day.py
# /content/drive/MyDrive/Data Engineering Project/dags
