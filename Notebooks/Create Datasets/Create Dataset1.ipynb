# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil
import os

source_path = '/content/dataset1_employees_initial_corrected.csv'
destination_dir = '/content/drive/MyDrive/Data Engineering Project/Datasets'

# Create the destination directory if it doesn't exist
os.makedirs(destination_dir, exist_ok=True)

# Construct the full destination path
destination_path = os.path.join(destination_dir, os.path.basename(source_path))

# Copy the file
shutil.copy(source_path, destination_path)

print(f"File copied successfully from '{source_path}' to '{destination_path}'")

# %%
# !pip install faker
# Out:
# Collecting faker
#   Downloading faker-38.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.12/dist-packages (from faker) (2025.2)
# Downloading faker-38.2.0-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 36.6 MB/s eta 0:00:00
# Installing collected packages: faker
# Successfully installed faker-38.2.0

# %%
from faker import Faker
import random
import pandas as pd
from datetime import datetime, timedelta

# %%
import pandas as pd
import random
import re
from faker import Faker
from datetime import datetime, timedelta

# --- Configuration ---
fake = Faker()
MIN_HIRE_DATE = datetime(2025, 1, 1).date() # Only applies to hire_date

# List definitions
POSITIONS = [
    "CG", "CNA", "CHHA", "LPN", "RN", "ADMIN",
]

RAW_STATUSES = [
    "Active",
    "Active - Not Currently Available",
    "Active - Expired Credentials",
    "Resigned/Separated - Eligible for Rehire",
    "Resigned/Separated - Not Eligible for Rehire",
    "Terminated - Unemployable"
]

VALID_RATINGS = [
    "0 - Not Applicable",
    "4 - Exceeds Expectations",
    "3 - Meets Expectations",
    "1 - Unacceptable"
]

EDUCATION = ["High School", "Associate Degree", "4 year College"]


# --- Cleaning Functions ---

def clean_phone(phone):
    """Clean phone number to XXX-XXX-XXXX format."""
    if not phone:
        return None
    digits = re.sub(r"\D", "", str(phone))
    if len(digits) == 11 and digits.startswith("1"):
        digits = digits[1:]
    if len(digits) != 10:
        return None
    return f"{digits[:3]}-{digits[3:6]}-{digits[6:]}"

def clean_hire_date(hire_date, min_date=MIN_HIRE_DATE):
    """Ensure hire_date is not before MIN_HIRE_DATE (01/01/2025)."""
    if pd.isna(hire_date) or hire_date is None:
        return None

    # Ensure date is a date object
    if isinstance(hire_date, str):
        try:
            hire_date = pd.to_datetime(hire_date).date()
        except:
            return None

    # Check if hire_date is before the minimum required date
    if hire_date < min_date:
        # Shift forward by a random number of days from the minimum date, up to 1 year
        return min_date + timedelta(days=random.randint(0, 365))
    return hire_date

def clean_pay(rate):
    """Enforce pay rate between $15 and $75."""
    try:
        rate = float(rate)
        return min(max(rate, 15), 75)
    except:
        return None

# --- Main Generation Function ---

def generate_employee(employee_id_counter):
    """Generates a single, realistic, and clean employee record."""

    # 1. Generate core dates/age
    age = random.randint(19, 86)
    # Generate DOB realistically (can be historical)
    dob = fake.date_of_birth(minimum_age=age, maximum_age=age)

    # Generate a potential hire date (can be historical for the purpose of simulating old data,
    # but it will be cleaned/clamped later)
    potential_hire_date = fake.date_between(start_date='-18y', end_date='today')

    # 2. Generate dependent dates (based on historical date generation)
    # Ensure dependent dates are after the potential hire date (or near it)
    last_shift_date = fake.date_between(potential_hire_date, 'today')
    last_appraisal_date = fake.date_between(potential_hire_date, 'today')
    next_appraisal_date = fake.date_between('today', '+1y')
    cpr_date = fake.date_between('-2y', 'today')

    # 3. Compile raw data dictionary
    employee_data = {
        "employee_id": employee_id_counter,
        "first_name": fake.first_name(),
        "last_name": fake.last_name(),
        "address": fake.street_address(),
        "city": fake.city(),
        "state": fake.state_abbr(),
        "zip": fake.zipcode(),
        "primary_phone": fake.phone_number(),
        "email": fake.email(),
        "status": random.choice(RAW_STATUSES),
        "last_shift_date": last_shift_date,
        "position": random.choice(POSITIONS),
        "base_pay_rate": random.uniform(15, 75),
        "current_rating": random.choice(VALID_RATINGS),
        "last_appraisal_date": last_appraisal_date,
        "next_appraisal_date": next_appraisal_date,
        "hire_date": potential_hire_date,
        "terminated_date": None,
        "rehire_date": None,
        "cpr_date": cpr_date,
        "pto_balance": random.randint(0, 45),
        "commitment_hours": random.randint(0, 40),
        "age": age,
        "dob": dob,
        "gender": random.choice(["Male", "Female"]),
        "education": random.choice(EDUCATION),
        "languages": random.choice(["English", "English, Spanish", "English, French"]),
        "emergency_contact": fake.name(),
        "emergency_contact_phone": fake.phone_number(),
        "emergency_instructions": fake.sentence()
    }

    # 4. Apply cleaning/validation
    employee_data["primary_phone"] = clean_phone(employee_data["primary_phone"])
    employee_data["emergency_contact_phone"] = clean_phone(employee_data["emergency_contact_phone"])
    employee_data["base_pay_rate"] = clean_pay(employee_data["base_pay_rate"])

    # Apply date cleaning ONLY to the hire_date
    employee_data["hire_date"] = clean_hire_date(employee_data["hire_date"])

    return employee_data

# --- Execution ---

DATASET_SIZE = 30
data = []
for i in range(1, DATASET_SIZE + 1):
    data.append(generate_employee(i))

df = pd.DataFrame(data)

# Save the final cleaned dataset
OUTPUT_FILENAME = "dataset1_employees_initial_corrected.csv"
df.to_csv(OUTPUT_FILENAME, index=False)

print(f"Successfully generated and cleaned {DATASET_SIZE} rows.")
print(f"Saved to: {OUTPUT_FILENAME}")
print("\nFirst 5 rows of the generated dataset (Note: Historical dates are now allowed for non-hire columns):")
print(df.head(30).to_markdown(index=False))
# Out:
# Successfully generated and cleaned 30 rows.
# Saved to: dataset1_employees_initial_corrected.csv
#
# First 5 rows of the generated dataset (Note: Historical dates are now allowed for non-hire columns):
# |   employee_id | first_name   | last_name   | address                            | city           | state   |   zip | primary_phone   | email                        | status                                       | last_shift_date   | position   |   base_pay_rate | current_rating           | last_appraisal_date   | next_appraisal_date   | hire_date   | terminated_date   | rehire_date   | cpr_date   |   pto_balance |   commitment_hours |   age | dob        | gender   | education        | languages        | emergency_contact   | emergency_contact_phone   | emergency_instructions                                   |
# |--------------:|:-------------|:------------|:-----------------------------------|:---------------|:--------|------:|:----------------|:-----------------------------|:---------------------------------------------|:------------------|:-----------|----------------:|:-------------------------|:----------------------|:----------------------|:------------|:------------------|:--------------|:-----------|--------------:|-------------------:|------:|:-----------|:---------|:-----------------|:-----------------|:--------------------|:--------------------------|:---------------------------------------------------------|
# |             1 | Lauren       | Rivera      | 56611 Baker Station Suite 046      | Harrisonport   | FM      | 95869 | 253-361-4272    | reyescheryl@example.com      | Active - Expired Credentials                 | 2021-03-24        | LPN        |         48.0583 | 3 - Meets Expectations   | 2013-10-05            | 2026-08-23            | 2025-10-04  |                   |               | 2025-08-20 |            31 |                 12 |    22 | 2003-02-28 | Female   | Associate Degree | English, French  | Melody Stewart      | 621-706-1774              | Most indeed ok such head.                                |
# |             2 | Carrie       | Jackson     | 457 Jackson Brook Apt. 780         | Ramosview      | OK      | 62122 | 627-330-7986    | erush@example.com            | Active                                       | 2025-10-16        | ADMIN      |         27.5371 | 0 - Not Applicable       | 2025-09-11            | 2026-10-12            | 2025-09-03  |                   |               | 2025-07-09 |            20 |                 15 |    53 | 1972-05-01 | Female   | 4 year College   | English, French  | Jonathan Miller     |                           | Near player do common however.                           |
# |             3 | Alexandra    | Mcdaniel    | 805 Karen Stravenue Apt. 699       | Williamtown    | NE      | 15845 |                 | ellisonamy@example.org       | Active - Expired Credentials                 | 2018-09-19        | CHHA       |         70.3561 | 1 - Unacceptable         | 2023-09-04            | 2026-01-03            | 2025-12-24  |                   |               | 2025-09-01 |            22 |                 20 |    52 | 1973-09-16 | Male     | Associate Degree | English, Spanish | Lisa Shields        |                           | From here lay federal charge will.                       |
# |             4 | Vanessa      | Green       | 274 Emily Corner                   | Port Amber     | PW      | 57268 |                 | antonio28@example.com        | Resigned/Separated - Eligible for Rehire     | 2015-12-31        | ADMIN      |         21.227  | 3 - Meets Expectations   | 2008-05-23            | 2026-01-26            | 2025-01-17  |                   |               | 2024-10-11 |            14 |                 29 |    82 | 1943-11-16 | Female   | Associate Degree | English, Spanish | Morgan White        |                           | Level relationship maybe big rich.                       |
# |             5 | Jonathon     | Rowe        | 383 Veronica Place                 | Bethanyburgh   | MS      | 78288 | 549-784-1414    | johnwheeler@example.org      | Resigned/Separated - Not Eligible for Rehire | 2024-06-28        | CG         |         64.1562 | 1 - Unacceptable         | 2025-05-03            | 2026-03-07            | 2025-06-13  |                   |               | 2025-05-15 |            11 |                 25 |    74 | 1951-09-07 | Male     | 4 year College   | English, French  | Jennifer Lopez      |                           | Require skill statement thing per.                       |
# |             6 | Angela       | Davis       | 414 Bell Terrace Suite 574         | Johnsonland    | CA      | 48397 |                 | vsmith@example.com           | Active                                       | 2021-07-31        | LPN        |         40.0397 | 1 - Unacceptable         | 2017-05-25            | 2026-07-18            | 2025-12-19  |                   |               | 2025-02-09 |             6 |                  6 |    64 | 1961-10-11 | Male     | Associate Degree | English          | Gary Banks          |                           | Most trade serve serve notice discussion science.        |
# |             7 | Adrian       | Olsen       | 812 Thomas Ramp Suite 773          | North Fredview | VI      | 42732 |                 | schaeferkimberly@example.org | Active                                       | 2011-12-17        | ADMIN      |         16.2175 | 0 - Not Applicable       | 2023-06-15            | 2025-12-22            | 2025-09-18  |                   |               | 2025-05-24 |            39 |                  7 |    61 | 1964-09-11 | Male     | High School      | English, French  | Erica Nichols       |                           | Main various of happen team.                             |
# |             8 | Angela       | Williams    | 0876 Fuller Ways Apt. 106          | Powellhaven    | GU      | 62619 |                 | shafferaimee@example.net     | Active                                       | 2025-09-20        | RN         |         20.938  | 3 - Meets Expectations   | 2025-12-07            | 2026-08-06            | 2025-07-13  |                   |               | 2023-12-27 |            15 |                 24 |    29 | 1996-06-21 | Female   | Associate Degree | English, Spanish | Stephanie Woods     |                           | Their total ago color specific can effect hot.           |
# |             9 | Stacy        | Black       | 144 Benjamin Summit Apt. 908       | New Valerie    | WI      | 79781 | 453-635-6297    | hjohnson@example.com         | Resigned/Separated - Eligible for Rehire     | 2018-06-19        | LPN        |         46.4628 | 0 - Not Applicable       | 2022-01-22            | 2026-10-15            | 2025-05-22  |                   |               | 2025-04-20 |            31 |                 28 |    19 | 2006-07-31 | Male     | High School      | English, Spanish | Leslie Patton       | 625-740-1821              | Clear present property seat.                             |
# |            10 | Jennifer     | Green       | 42790 Gibson Views Apt. 785        | Port Keithbury | HI      | 26822 |                 | matthew34@example.net        | Active - Not Currently Available             | 2019-01-30        | RN         |         42.7864 | 0 - Not Applicable       | 2024-01-24            | 2026-03-26            | 2025-11-16  |                   |               | 2024-01-26 |            44 |                  3 |    29 | 1996-08-23 | Male     | 4 year College   | English, Spanish | David Baker         | 586-440-6123              | Break anything far along Democrat successful.            |
# |            11 | Michael      | Walsh       | 76717 Martinez Lodge Apt. 725      | Kennethland    | IL      | 37024 |                 | stanleymiguel@example.net    | Terminated - Unemployable                    | 2024-04-04        | CG         |         39.0865 | 4 - Exceeds Expectations | 2024-05-18            | 2026-01-29            | 2025-02-09  |                   |               | 2025-11-14 |            42 |                  2 |    51 | 1974-01-09 | Female   | Associate Degree | English, French  | Nicole Caldwell     |                           | Mr use early author then production.                     |
# |            12 | Jonathan     | Brown       | 80066 Cox Dam                      | Isaacborough   | NC      | 56326 |                 | holly41@example.org          | Active - Not Currently Available             | 2025-02-08        | LPN        |         55.2972 | 4 - Exceeds Expectations | 2025-03-19            | 2025-12-24            | 2025-03-05  |                   |               | 2025-08-13 |            22 |                 29 |    24 | 2001-08-09 | Female   | 4 year College   | English, French  | Charles Dalton      |                           | Leave something write only leader star standard.         |
# |            13 | Patricia     | Grant       | 7215 Cheyenne Freeway Suite 897    | Jonesville     | FM      | 08064 |                 | xramirez@example.com         | Active - Not Currently Available             | 2022-06-21        | LPN        |         16.326  | 1 - Unacceptable         | 2022-09-26            | 2026-07-31            | 2025-06-08  |                   |               | 2024-09-08 |            28 |                 16 |    51 | 1974-05-23 | Male     | Associate Degree | English, Spanish | Chase Fleming       | 990-478-1028              | While arrive stuff.                                      |
# |            14 | Anthony      | Hardin      | 24570 Amy Spurs                    | Raybury        | MP      | 03681 |                 | ellislindsey@example.org     | Resigned/Separated - Not Eligible for Rehire | 2016-02-21        | CNA        |         68.9127 | 3 - Meets Expectations   | 2014-04-13            | 2026-01-05            | 2025-12-11  |                   |               | 2024-09-28 |            11 |                 10 |    22 | 2003-01-10 | Female   | High School      | English          | Ryan Adams          |                           | Apply decade its hot include just nature myself.         |
# |            15 | Rachel       | Williams    | 86117 Vincent Expressway Suite 151 | Pedroview      | MN      | 83640 | 744-828-7432    | brandymiller@example.net     | Resigned/Separated - Eligible for Rehire     | 2025-05-17        | LPN        |         24.702  | 4 - Exceeds Expectations | 2022-03-13            | 2026-04-11            | 2025-11-26  |                   |               | 2024-12-13 |            28 |                  4 |    24 | 2001-06-17 | Female   | High School      | English, French  | Johnny Smith        | 784-428-4795              | Professional water above north individual add never.     |
# |            16 | Ryan         | Ball        | 2771 Carney Street Suite 685       | Grimeshaven    | NE      | 84142 | 555-289-5927    | mitchell23@example.com       | Active                                       | 2021-02-15        | CHHA       |         50.4673 | 0 - Not Applicable       | 2019-12-07            | 2026-05-08            | 2025-01-13  |                   |               | 2024-12-03 |             7 |                  3 |    67 | 1958-10-31 | Female   | 4 year College   | English          | Natalie Ellison     | 242-612-5382              | Education view hospital several figure necessary.        |
# |            17 | Joyce        | Patrick     | 149 Flynn Loaf Apt. 763            | Jennifermouth  | TN      | 64459 | 592-830-9156    | rwilson@example.net          | Terminated - Unemployable                    | 2021-01-12        | CG         |         34.5667 | 3 - Meets Expectations   | 2020-10-20            | 2026-05-03            | 2025-10-30  |                   |               | 2025-11-04 |            10 |                 21 |    68 | 1957-07-05 | Female   | Associate Degree | English          | Seth Boyd           | 321-319-2032              | So consider question whom couple note.                   |
# |            18 | Laura        | Ferguson    | 2621 Lee Bridge                    | Lake Meghan    | WA      | 38044 |                 | john97@example.net           | Active - Not Currently Available             | 2023-03-22        | LPN        |         33.8393 | 4 - Exceeds Expectations | 2025-03-31            | 2026-09-29            | 2025-03-09  |                   |               | 2025-09-01 |             9 |                 35 |    68 | 1957-10-03 | Female   | Associate Degree | English          | Eduardo Roberts     |                           | Movement buy anything machine should.                    |
# |            19 | William      | Sampson     | 4275 Franco Rue Apt. 009           | Kaylaside      | NY      | 31957 | 428-718-3095    | jenna63@example.net          | Active                                       | 2023-08-05        | RN         |         62.7924 | 1 - Unacceptable         | 2023-09-06            | 2026-07-23            | 2025-07-24  |                   |               | 2025-03-05 |            37 |                 35 |    60 | 1965-10-21 | Female   | 4 year College   | English          | Robert Jones        |                           | Attack every again direction together talk several.      |
# |            20 | Martha       | Buchanan    | 6719 Green Fields                  | Marymouth      | WI      | 85546 | 937-212-6794    | phillipparker@example.com    | Active - Not Currently Available             | 2023-07-14        | CG         |         58.1941 | 0 - Not Applicable       | 2019-06-09            | 2026-06-07            | 2025-03-11  |                   |               | 2024-07-05 |            32 |                 16 |    53 | 1972-04-08 | Male     | 4 year College   | English          | Tammy Hatfield      |                           | Seem computer alone wait close.                          |
# |            21 | John         | Williams    | 4244 Sara Vista                    | Shannonmouth   | LA      | 44416 | 683-634-8364    | aallen@example.org           | Active                                       | 2019-12-13        | LPN        |         29.5059 | 1 - Unacceptable         | 2025-05-04            | 2026-11-03            | 2025-05-27  |                   |               | 2025-02-28 |             6 |                 24 |    57 | 1968-02-10 | Female   | Associate Degree | English          | Steven Clark        |                           | Drop call effect mouth five.                             |
# |            22 | Dylan        | Gregory     | 80905 Olivia Ridges                | Riggsview      | NV      | 32852 | 312-523-9897    | alexanderblack@example.com   | Resigned/Separated - Eligible for Rehire     | 2019-02-12        | LPN        |         63.8271 | 1 - Unacceptable         | 2018-04-11            | 2026-11-27            | 2025-01-12  |                   |               | 2024-01-29 |            45 |                 16 |    67 | 1958-02-20 | Male     | 4 year College   | English          | Samantha Martin     | 249-822-7035              | Word institution drug suggest push party effort prevent. |
# |            23 | Timothy      | Peterson    | 13220 Smith Crossing               | Lake Wayne     | NJ      | 95375 | 926-636-9794    | cfreeman@example.net         | Terminated - Unemployable                    | 2023-08-30        | ADMIN      |         67.2298 | 1 - Unacceptable         | 2016-05-05            | 2026-06-17            | 2025-04-10  |                   |               | 2024-11-19 |            31 |                 34 |    32 | 1993-08-05 | Male     | Associate Degree | English, French  | Hailey Fox          | 573-546-4159              | High power current.                                      |
# |            24 | Robert       | Morris      | 701 Meyer Ridge Apt. 192           | Lawsonfurt     | PA      | 54367 |                 | jennifer39@example.com       | Active                                       | 2020-08-05        | RN         |         17.346  | 1 - Unacceptable         | 2025-03-25            | 2026-08-26            | 2025-02-06  |                   |               | 2024-09-16 |            32 |                  7 |    71 | 1954-05-07 | Female   | High School      | English          | Anthony Phillips    | 635-393-2997              | Area relationship edge affect.                           |
# |            25 | Tiffany      | Cole        | 38226 Tara Hollow                  | West Kim       | TX      | 88290 |                 | john32@example.net           | Resigned/Separated - Eligible for Rehire     | 2012-07-15        | CG         |         20.4681 | 1 - Unacceptable         | 2016-02-25            | 2026-08-16            | 2025-09-13  |                   |               | 2025-05-18 |            32 |                 35 |    45 | 1980-04-02 | Male     | 4 year College   | English, Spanish | Sean Short          |                           | Article history give anyone gas condition.               |
# |            26 | Matthew      | Myers       | 86465 Hancock Walks Apt. 617       | Reillymouth    | WA      | 02544 |                 | darren23@example.org         | Resigned/Separated - Eligible for Rehire     | 2025-10-07        | CHHA       |         17.3792 | 0 - Not Applicable       | 2025-10-23            | 2026-01-27            | 2025-09-03  |                   |               | 2025-01-04 |            19 |                 32 |    73 | 1952-07-25 | Female   | Associate Degree | English, Spanish | Dawn Wheeler        |                           | Else while huge before.                                  |
# |            27 | Spencer      | Gilbert     | 32345 Owens Alley                  | Lake Latasha   | NH      | 68151 |                 | alyssamullins@example.net    | Resigned/Separated - Eligible for Rehire     | 2023-08-20        | CNA        |         62.9457 | 4 - Exceeds Expectations | 2013-10-14            | 2026-01-15            | 2025-10-12  |                   |               | 2024-01-06 |            24 |                 34 |    74 | 1951-04-22 | Female   | Associate Degree | English, Spanish | Janet Taylor        |                           | Recent drive now think sort wrong apply.                 |
# |            28 | Sarah        | Newman      | 78827 Michelle Lights Apt. 905     | Jacobfurt      | WV      | 25898 |                 | ntorres@example.net          | Active                                       | 2024-04-14        | CNA        |         37.1427 | 3 - Meets Expectations   | 2025-10-16            | 2026-07-29            | 2025-03-26  |                   |               | 2025-06-27 |            44 |                 33 |    44 | 1981-07-23 | Female   | 4 year College   | English, French  | Jennifer Graham     | 947-532-0240              | Two green fine responsibility.                           |
# |            29 | William      | Johnston    | 36416 Jonathan Extension Apt. 697  | Chadmouth      | WY      | 86350 |                 | christopher28@example.org    | Active - Not Currently Available             | 2023-09-09        | CNA        |         37.5225 | 4 - Exceeds Expectations | 2023-02-18            | 2026-01-17            | 2025-10-16  |                   |               | 2025-09-19 |            44 |                 17 |    25 | 2000-12-10 | Female   | 4 year College   | English          | Sheila Williams     | 624-825-4209              | Customer as instead summer sit civil.                    |
# |            30 | Michelle     | Stafford    | 37766 Garcia Dam Apt. 729          | Taramouth      | IL      | 47986 |                 | walkervalerie@example.com    | Resigned/Separated - Eligible for Rehire     | 2024-06-23        | RN         |         71.3455 | 4 - Exceeds Expectations | 2024-04-23            | 2026-06-28            | 2025-02-05  |                   |               | 2025-11-18 |             0 |                 17 |    69 | 1956-05-10 | Female   | 4 year College   | English, Spanish | Marcus Pineda       | 826-499-8137              | Senior behind pull American about.                       |
